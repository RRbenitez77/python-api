# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(weather_api_key )
# Out:
# b9d30bcfc87f322ebe7a470f8acb4e3a

# %%
#Lists and counters
city_list = []
city_number =[]
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lats_list = []
lngs_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

print("Beginning Data Retrieval ")
print("-------------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop matching city names with city_list
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lats_list.append(response["coord"]["lat"])
        lngs_list.append(response["coord"]["lon"])
        temp_max_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 : georgetown
# Processing Record 2 of Set 1 : albany
# Processing Record 3 of Set 1 : nowa deba
# Processing Record 4 of Set 1 : krasnoarmeysk
# Processing Record 5 of Set 1 : novi troyany
# Processing Record 6 of Set 1 : mutsu
# Processing Record 7 of Set 1 : hilo
# Processing Record 8 of Set 1 : kununurra
# Processing Record 9 of Set 1 : mataura
# Processing Record 10 of Set 1 : deputatskiy
# Processing Record 11 of Set 1 : new norfolk
# City not found. Skipping...
# Processing Record 12 of Set 1 : tasiilaq
# Processing Record 13 of Set 1 : sompeta
# Processing Record 14 of Set 1 : ushuaia
# Processing Record 15 of Set 1 : isangel
# Processing Record 16 of Set 1 : kapaa
# Processing Record 17 of Set 1 : puerto ayora
# Processing Record 18 of Set 1 : kishi
# Processing Record 19 of Set 1 : jalu
# Processing Record 20 of Set 1 : lashio
# Processing Record 21 of Set 1 : tuatapere
# Processing Record 22 of Set 1 : iqaluit
# Processing Record 23 of Set 1 : atuona
# Processing Record 24 of Set 1 : korla
# Processing Record 25 of Set 1 : punta arenas
# Processing Record 26 of Set 1 : blagoyevo
# Processing Record 27 of Set 1 : clyde river
# Processing Record 28 of Set 1 : khatanga
# Processing Record 29 of Set 1 : kodiak
# Processing Record 30 of Set 1 : road town
# City not found. Skipping...
# Processing Record 31 of Set 1 : arraial do cabo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 1 : ancud
# Processing Record 33 of Set 1 : nikolskoye
# Processing Record 34 of Set 1 : zaozerne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 1 : shimoda
# Processing Record 36 of Set 1 : garissa
# Processing Record 37 of Set 1 : portland
# Processing Record 38 of Set 1 : qaanaaq
# Processing Record 39 of Set 1 : provideniya
# Processing Record 40 of Set 1 : port blair
# Processing Record 41 of Set 1 : bluff
# Processing Record 42 of Set 1 : port alfred
# City not found. Skipping...
# Processing Record 43 of Set 1 : sitka
# Processing Record 44 of Set 1 : porto novo
# Processing Record 45 of Set 1 : tilichiki
# Processing Record 46 of Set 1 : dubti
# Processing Record 47 of Set 1 : nichinan
# Processing Record 48 of Set 1 : mitu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 1 : bredasdorp
# Processing Record 50 of Set 1 : quzhou
# Processing Record 0 of Set 2 : cidreira
# Processing Record 1 of Set 2 : ponta do sol
# Processing Record 2 of Set 2 : nyurba
# Processing Record 3 of Set 2 : esperance
# Processing Record 4 of Set 2 : cape town
# Processing Record 5 of Set 2 : lethem
# Processing Record 6 of Set 2 : narsipatnam
# Processing Record 7 of Set 2 : zhigansk
# Processing Record 8 of Set 2 : rikitea
# Processing Record 9 of Set 2 : pevek
# Processing Record 10 of Set 2 : vammala
# Processing Record 11 of Set 2 : victor harbor
# Processing Record 12 of Set 2 : presidente medici
# Processing Record 13 of Set 2 : yumen
# Processing Record 14 of Set 2 : pianco
# Processing Record 15 of Set 2 : faya
# Processing Record 16 of Set 2 : saint-philippe
# Processing Record 17 of Set 2 : mujiayingzi
# Processing Record 18 of Set 2 : butaritari
# Processing Record 19 of Set 2 : jamestown
# City not found. Skipping...
# Processing Record 20 of Set 2 : komsomolskiy
# Processing Record 21 of Set 2 : castro
# Processing Record 22 of Set 2 : matara
# Processing Record 23 of Set 2 : eregli
# Processing Record 24 of Set 2 : talcahuano
# Processing Record 25 of Set 2 : barrow
# Processing Record 26 of Set 2 : faanui
# Processing Record 27 of Set 2 : iralaya
# Processing Record 28 of Set 2 : mahebourg
# Processing Record 29 of Set 2 : kavieng
# Processing Record 30 of Set 2 : bardiyah
# Processing Record 31 of Set 2 : tuktoyaktuk
# City not found. Skipping...
# Processing Record 32 of Set 2 : talaya
# Processing Record 33 of Set 2 : sosua
# Processing Record 34 of Set 2 : norman wells
# Processing Record 35 of Set 2 : biak
# Processing Record 36 of Set 2 : hobart
# Processing Record 37 of Set 2 : kavaratti
# Processing Record 38 of Set 2 : yellowknife
# Processing Record 39 of Set 2 : praya
# Processing Record 40 of Set 2 : severo-kurilsk
# Processing Record 41 of Set 2 : llaillay
# Processing Record 42 of Set 2 : madimba
# Processing Record 43 of Set 2 : mandurah
# Processing Record 44 of Set 2 : mar del plata
# Processing Record 45 of Set 2 : touros
# Processing Record 46 of Set 2 : hermanus
# Processing Record 47 of Set 2 : svetlogorsk
# Processing Record 48 of Set 2 : velikiy ustyug
# Processing Record 49 of Set 2 : lahaina
# Processing Record 50 of Set 2 : nsoko
# Processing Record 0 of Set 3 : vaini
# Processing Record 1 of Set 3 : tres picos
# Processing Record 2 of Set 3 : broken hill
# City not found. Skipping...
# Processing Record 3 of Set 3 : tiznit
# Processing Record 4 of Set 3 : nanortalik
# Processing Record 5 of Set 3 : pokhara
# Processing Record 6 of Set 3 : cockburn town
# Processing Record 7 of Set 3 : pisco
# Processing Record 8 of Set 3 : fos-sur-mer
# City not found. Skipping...
# Processing Record 9 of Set 3 : caravelas
# Processing Record 10 of Set 3 : morant bay
# Processing Record 11 of Set 3 : yakeshi
# Processing Record 12 of Set 3 : vao
# Processing Record 13 of Set 3 : cooma
# Processing Record 14 of Set 3 : lerwick
# Processing Record 15 of Set 3 : alofi
# Processing Record 16 of Set 3 : jardim
# City not found. Skipping...
# Processing Record 17 of Set 3 : kamenka
# Processing Record 18 of Set 3 : port hardy
# Processing Record 19 of Set 3 : kalmunai
# Processing Record 20 of Set 3 : matay
# Processing Record 21 of Set 3 : muros
# Processing Record 22 of Set 3 : zhovtneve
# Processing Record 23 of Set 3 : salisbury
# Processing Record 24 of Set 3 : talas
# Processing Record 25 of Set 3 : alexandria
# Processing Record 26 of Set 3 : busselton
# Processing Record 27 of Set 3 : anshun
# Processing Record 28 of Set 3 : alappuzha
# Processing Record 29 of Set 3 : upernavik
# Processing Record 30 of Set 3 : chokurdakh
# Processing Record 31 of Set 3 : bethel
# Processing Record 32 of Set 3 : thompson
# Processing Record 33 of Set 3 : carnarvon
# City not found. Skipping...
# Processing Record 34 of Set 3 : hithadhoo
# Processing Record 35 of Set 3 : fortuna
# Processing Record 36 of Set 3 : zonguldak
# City not found. Skipping...
# Processing Record 37 of Set 3 : longyearbyen
# Processing Record 38 of Set 3 : sao filipe
# Processing Record 39 of Set 3 : moose factory
# Processing Record 40 of Set 3 : avarua
# Processing Record 41 of Set 3 : qixia
# Processing Record 42 of Set 3 : ternate
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 3 : lata
# Processing Record 44 of Set 3 : beyneu
# Processing Record 45 of Set 3 : fallon
# Processing Record 46 of Set 3 : cairns
# Processing Record 47 of Set 3 : abramovka
# Processing Record 48 of Set 3 : dikson
# Processing Record 49 of Set 3 : naze
# Processing Record 50 of Set 3 : lock haven
# Processing Record 0 of Set 4 : talnakh
# Processing Record 1 of Set 4 : airai
# Processing Record 2 of Set 4 : sept-iles
# Processing Record 3 of Set 4 : gat
# Processing Record 4 of Set 4 : kasongo-lunda
# Processing Record 5 of Set 4 : taldan
# Processing Record 6 of Set 4 : avon
# Processing Record 7 of Set 4 : tarboro
# Processing Record 8 of Set 4 : si racha
# Processing Record 9 of Set 4 : saint-pierre
# Processing Record 10 of Set 4 : benghazi
# Processing Record 11 of Set 4 : nemuro
# Processing Record 12 of Set 4 : bambous virieux
# Processing Record 13 of Set 4 : inhambane
# Processing Record 14 of Set 4 : ribeira grande
# City not found. Skipping...
# Processing Record 15 of Set 4 : charters towers
# Processing Record 16 of Set 4 : puerto baquerizo moreno
# Processing Record 17 of Set 4 : rocha
# Processing Record 18 of Set 4 : pitimbu
# Processing Record 19 of Set 4 : myitkyina
# City not found. Skipping...
# Processing Record 20 of Set 4 : dingle
# Processing Record 21 of Set 4 : kruisfontein
# Processing Record 22 of Set 4 : port hope
# Processing Record 23 of Set 4 : thunder bay
# Processing Record 24 of Set 4 : port lincoln
# Processing Record 25 of Set 4 : okhotsk
# Processing Record 26 of Set 4 : noyabrsk
# Processing Record 27 of Set 4 : ceres
# Processing Record 28 of Set 4 : guerrero negro
# Processing Record 29 of Set 4 : oktyabrskoye
# Processing Record 30 of Set 4 : souillac
# Processing Record 31 of Set 4 : povenets
# Processing Record 32 of Set 4 : north bend
# Processing Record 33 of Set 4 : miraflores
# Processing Record 34 of Set 4 : east london
# Processing Record 35 of Set 4 : sola
# Processing Record 36 of Set 4 : shenjiamen
# Processing Record 37 of Set 4 : xining
# Processing Record 38 of Set 4 : yerbogachen
# Processing Record 39 of Set 4 : ust-maya
# Processing Record 40 of Set 4 : kasongo
# Processing Record 41 of Set 4 : northam
# Processing Record 42 of Set 4 : port hedland
# Processing Record 43 of Set 4 : nouadhibou
# Processing Record 44 of Set 4 : wanning
# Processing Record 45 of Set 4 : bathsheba
# Processing Record 46 of Set 4 : stepnogorsk
# Processing Record 47 of Set 4 : hambantota
# City not found. Skipping...
# Processing Record 48 of Set 4 : bantry
# Processing Record 49 of Set 4 : lebu
# Processing Record 50 of Set 4 : vila franca do campo
# Processing Record 0 of Set 5 : geraldton
# Processing Record 1 of Set 5 : san angelo
# Processing Record 2 of Set 5 : akyab
# Processing Record 3 of Set 5 : lagoa
# Processing Record 4 of Set 5 : namibe
# Processing Record 5 of Set 5 : penzance
# Processing Record 6 of Set 5 : tateyama
# Processing Record 7 of Set 5 : noumea
# City not found. Skipping...
# Processing Record 8 of Set 5 : kautokeino
# Processing Record 9 of Set 5 : atambua
# Processing Record 10 of Set 5 : saskylakh
# Processing Record 11 of Set 5 : daru
# Processing Record 12 of Set 5 : narsaq
# City not found. Skipping...
# Processing Record 13 of Set 5 : darnah
# Processing Record 14 of Set 5 : saint anthony
# Processing Record 15 of Set 5 : namatanai
# Processing Record 16 of Set 5 : graham
# Processing Record 17 of Set 5 : chara
# Processing Record 18 of Set 5 : saldanha
# Processing Record 19 of Set 5 : torit
# Processing Record 20 of Set 5 : ayagoz
# Processing Record 21 of Set 5 : marawi
# Processing Record 22 of Set 5 : westport
# Processing Record 23 of Set 5 : golpayegan
# Processing Record 24 of Set 5 : korsakov
# Processing Record 25 of Set 5 : baykit
# Processing Record 26 of Set 5 : bagdarin
# City not found. Skipping...
# Processing Record 27 of Set 5 : sampit
# Processing Record 28 of Set 5 : mayor pablo lagerenza
# Processing Record 29 of Set 5 : qui nhon
# Processing Record 30 of Set 5 : padang
# Processing Record 31 of Set 5 : vaitape
# Processing Record 32 of Set 5 : beringovskiy
# Processing Record 33 of Set 5 : xuddur
# Processing Record 34 of Set 5 : mlowo
# Processing Record 35 of Set 5 : kahului
# Processing Record 36 of Set 5 : semirom
# Processing Record 37 of Set 5 : emerald
# Processing Record 38 of Set 5 : hawalli
# Processing Record 39 of Set 5 : marsaxlokk
# Processing Record 40 of Set 5 : sinnamary
# Processing Record 41 of Set 5 : margate
# Processing Record 42 of Set 5 : at-bashi
# Processing Record 43 of Set 5 : ugoofaaru
# Processing Record 44 of Set 5 : turukhansk
# Processing Record 45 of Set 5 : bac lieu
# Processing Record 46 of Set 5 : weymouth
# Processing Record 47 of Set 5 : verkhnyaya inta
# Processing Record 48 of Set 5 : sur
# Processing Record 49 of Set 5 : amahai
# Processing Record 50 of Set 5 : alugan
# Processing Record 0 of Set 6 : yangshan
# Processing Record 1 of Set 6 : tabas
# Processing Record 2 of Set 6 : aklavik
# Processing Record 3 of Set 6 : praia da vitoria
# Processing Record 4 of Set 6 : port moresby
# Processing Record 5 of Set 6 : chuy
# Processing Record 6 of Set 6 : khani
# Processing Record 7 of Set 6 : aquiraz
# Processing Record 8 of Set 6 : phitsanulok
# Processing Record 9 of Set 6 : udachnyy
# Processing Record 10 of Set 6 : tuy hoa
# Processing Record 11 of Set 6 : baghdad
# Processing Record 12 of Set 6 : henties bay
# Processing Record 13 of Set 6 : cabra
# Processing Record 14 of Set 6 : buchanan
# City not found. Skipping...
# Processing Record 15 of Set 6 : beira
# Processing Record 16 of Set 6 : port elizabeth
# Processing Record 17 of Set 6 : ibb
# Processing Record 18 of Set 6 : soe
# Processing Record 19 of Set 6 : the valley
# Processing Record 20 of Set 6 : rio grande
# Processing Record 21 of Set 6 : anadyr
# City not found. Skipping...
# Processing Record 22 of Set 6 : ojinaga
# Processing Record 23 of Set 6 : state college
# Processing Record 24 of Set 6 : black river
# Processing Record 25 of Set 6 : belmonte
# Processing Record 26 of Set 6 : rio gallegos
# Processing Record 27 of Set 6 : zapolyarnyy
# Processing Record 28 of Set 6 : san jeronimo
# Processing Record 29 of Set 6 : tongliao
# Processing Record 30 of Set 6 : deep river
# Processing Record 31 of Set 6 : coquimbo
# City not found. Skipping...
# Processing Record 32 of Set 6 : salalah
# Processing Record 33 of Set 6 : college
# Processing Record 34 of Set 6 : arlit
# Processing Record 35 of Set 6 : tocopilla
# Processing Record 36 of Set 6 : seoul
# Processing Record 37 of Set 6 : corinto
# Processing Record 38 of Set 6 : itarema
# City not found. Skipping...
# Processing Record 39 of Set 6 : muli
# Processing Record 40 of Set 6 : chokwe
# Processing Record 41 of Set 6 : hamilton
# Processing Record 42 of Set 6 : cartagena del chaira
# Processing Record 43 of Set 6 : luganville
# Processing Record 44 of Set 6 : mount gambier
# Processing Record 45 of Set 6 : gizo
# Processing Record 46 of Set 6 : batemans bay
# Processing Record 47 of Set 6 : olinda
# Processing Record 48 of Set 6 : vardo
# Processing Record 49 of Set 6 : hasaki
# Processing Record 50 of Set 6 : uyemskiy
# Processing Record 0 of Set 7 : ronne
# Processing Record 1 of Set 7 : olafsvik
# City not found. Skipping...
# Processing Record 2 of Set 7 : ariquemes
# Processing Record 3 of Set 7 : nabire
# Processing Record 4 of Set 7 : alta floresta
# Processing Record 5 of Set 7 : mantua
# Processing Record 6 of Set 7 : bourail
# Processing Record 7 of Set 7 : svecha
# Processing Record 8 of Set 7 : linhares
# Processing Record 9 of Set 7 : anjozorobe
# Processing Record 10 of Set 7 : jatiroto
# Processing Record 11 of Set 7 : yulara
# City not found. Skipping...
# Processing Record 12 of Set 7 : nacala
# Processing Record 13 of Set 7 : laem sing
# City not found. Skipping...
# Processing Record 14 of Set 7 : kishtwar
# Processing Record 15 of Set 7 : rayong
# Processing Record 16 of Set 7 : codrington
# Processing Record 17 of Set 7 : lotofaga
# City not found. Skipping...
# Processing Record 18 of Set 7 : christchurch
# Processing Record 19 of Set 7 : mogzon
# Processing Record 20 of Set 7 : arman
# Processing Record 21 of Set 7 : cap malheureux
# Processing Record 22 of Set 7 : atar
# Processing Record 23 of Set 7 : san patricio
# Processing Record 24 of Set 7 : victoria
# Processing Record 25 of Set 7 : pudozh
# Processing Record 26 of Set 7 : samarai
# Processing Record 27 of Set 7 : pemberton
# Processing Record 28 of Set 7 : constitucion
# Processing Record 29 of Set 7 : vestmannaeyjar
# Processing Record 30 of Set 7 : chapais
# City not found. Skipping...
# Processing Record 31 of Set 7 : sesheke
# Processing Record 32 of Set 7 : andenes
# Processing Record 33 of Set 7 : half moon bay
# Processing Record 34 of Set 7 : vallenar
# Processing Record 35 of Set 7 : antofagasta
# Processing Record 36 of Set 7 : nanakuli
# Processing Record 37 of Set 7 : ilabaya
# Processing Record 38 of Set 7 : port macquarie
# Processing Record 39 of Set 7 : brekstad
# Processing Record 40 of Set 7 : bergen
# Processing Record 41 of Set 7 : le port
# Processing Record 42 of Set 7 : ekimchan
# Processing Record 43 of Set 7 : itoman
# Processing Record 44 of Set 7 : wufeng
# Processing Record 45 of Set 7 : el alto
# Processing Record 46 of Set 7 : nome
# Processing Record 47 of Set 7 : sioux lookout
# Processing Record 48 of Set 7 : caninde
# Processing Record 49 of Set 7 : ulladulla
# Processing Record 50 of Set 7 : sharjah
# Processing Record 0 of Set 8 : panlaitan
# Processing Record 1 of Set 8 : jining
# Processing Record 2 of Set 8 : yangambi
# Processing Record 3 of Set 8 : hanko
# Processing Record 4 of Set 8 : babstovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 8 : robat karim
# Processing Record 6 of Set 8 : yantzaza
# Processing Record 7 of Set 8 : rawson
# Processing Record 8 of Set 8 : cherskiy
# Processing Record 9 of Set 8 : ferrol
# Processing Record 10 of Set 8 : meulaboh
# Processing Record 11 of Set 8 : teguldet
# Processing Record 12 of Set 8 : okha
# Processing Record 13 of Set 8 : hami
# City not found. Skipping...
# Processing Record 14 of Set 8 : bengkulu
# Processing Record 15 of Set 8 : sisimiut
# City not found. Skipping...
# Processing Record 16 of Set 8 : lakki marwat
# Processing Record 17 of Set 8 : coronado
# Processing Record 18 of Set 8 : aiquile
# Processing Record 19 of Set 8 : san quintin
# Processing Record 20 of Set 8 : tiksi
# Processing Record 21 of Set 8 : carutapera
# Processing Record 22 of Set 8 : sorland
# Processing Record 23 of Set 8 : klaksvik
# City not found. Skipping...
# Processing Record 24 of Set 8 : ulaangom
# Processing Record 25 of Set 8 : port augusta
# Processing Record 26 of Set 8 : bridlington
# Processing Record 27 of Set 8 : dunedin
# Processing Record 28 of Set 8 : japura
# Processing Record 29 of Set 8 : auki
# Processing Record 30 of Set 8 : ilulissat
# Processing Record 31 of Set 8 : laguna
# Processing Record 32 of Set 8 : kerema
# Processing Record 33 of Set 8 : pangnirtung
# Processing Record 34 of Set 8 : tevaitoa
# Processing Record 35 of Set 8 : strezhevoy
# Processing Record 36 of Set 8 : bruck an der leitha
# Processing Record 37 of Set 8 : khandyga
# Processing Record 38 of Set 8 : labuhan
# Processing Record 39 of Set 8 : petropavlovsk-kamchatskiy
# Processing Record 40 of Set 8 : bonthe
# City not found. Skipping...
# Processing Record 41 of Set 8 : san cristobal
# Processing Record 42 of Set 8 : popondetta
# Processing Record 43 of Set 8 : pandamatenga
# Processing Record 44 of Set 8 : bandarbeyla
# Processing Record 45 of Set 8 : yei
# Processing Record 46 of Set 8 : agirish
# Processing Record 47 of Set 8 : dombarovskiy
# Processing Record 48 of Set 8 : ust-ilimsk
# Processing Record 49 of Set 8 : yinchuan
# Processing Record 50 of Set 8 : leningradskiy
# Processing Record 0 of Set 9 : reisterstown
# Processing Record 1 of Set 9 : east wenatchee bench
# Processing Record 2 of Set 9 : bodden town
# Processing Record 3 of Set 9 : tygda
# Processing Record 4 of Set 9 : west helena
# Processing Record 5 of Set 9 : mwense
# Processing Record 6 of Set 9 : odessa
# Processing Record 7 of Set 9 : kijang
# Processing Record 8 of Set 9 : puro
# Processing Record 9 of Set 9 : antsohihy
# Processing Record 10 of Set 9 : sao felix do xingu
# Processing Record 11 of Set 9 : caconde
# Processing Record 12 of Set 9 : coolum beach
# Processing Record 13 of Set 9 : goderich
# Processing Record 14 of Set 9 : puerto del rosario
# Processing Record 15 of Set 9 : lompoc
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 9 : wajima
# Processing Record 17 of Set 9 : mecca
# Processing Record 18 of Set 9 : erenhot
# Processing Record 19 of Set 9 : wamba
# Processing Record 20 of Set 9 : mikhaylovka
# City not found. Skipping...
# Processing Record 21 of Set 9 : kutum
# Processing Record 22 of Set 9 : pamanukan
# City not found. Skipping...
# Processing Record 23 of Set 9 : vilyuysk
# Processing Record 24 of Set 9 : sakakah
# Processing Record 25 of Set 9 : kiama
# Processing Record 26 of Set 9 : mao
# Processing Record 27 of Set 9 : guantanamo
# Processing Record 28 of Set 9 : rock sound
# Processing Record 29 of Set 9 : fukue
# Processing Record 30 of Set 9 : nara
# Processing Record 31 of Set 9 : torbay
# Processing Record 32 of Set 9 : simpang
# Processing Record 33 of Set 9 : macas
# Processing Record 34 of Set 9 : aksarka
# Processing Record 35 of Set 9 : sambava
# Processing Record 36 of Set 9 : kungurtug
# City not found. Skipping...
# Processing Record 37 of Set 9 : brae
# Processing Record 38 of Set 9 : venice
# Processing Record 39 of Set 9 : podgornoye
# Processing Record 40 of Set 9 : mareeba
# Processing Record 41 of Set 9 : flin flon
# Processing Record 42 of Set 9 : changli
# Processing Record 43 of Set 9 : butterworth
# Processing Record 44 of Set 9 : tarakan
# Processing Record 45 of Set 9 : paita
# Processing Record 46 of Set 9 : balikpapan
# Processing Record 47 of Set 9 : orapa
# Processing Record 48 of Set 9 : west bay
# Processing Record 49 of Set 9 : shihezi
# Processing Record 50 of Set 9 : fukuma
# Processing Record 0 of Set 10 : kidal
# Processing Record 1 of Set 10 : uarini
# Processing Record 2 of Set 10 : aripuana
# Processing Record 3 of Set 10 : saint george
# Processing Record 4 of Set 10 : kongoussi
# Processing Record 5 of Set 10 : umm lajj
# Processing Record 6 of Set 10 : poindimie
# Processing Record 7 of Set 10 : tomatlan
# Processing Record 8 of Set 10 : avera
# Processing Record 9 of Set 10 : kollo
# Processing Record 10 of Set 10 : luena
# Processing Record 11 of Set 10 : yamada
# Processing Record 12 of Set 10 : eureka
# Processing Record 13 of Set 10 : flinders
# Processing Record 14 of Set 10 : samarkand
# Processing Record 15 of Set 10 : melville
# Processing Record 16 of Set 10 : muswellbrook
# Processing Record 17 of Set 10 : taltal
# Processing Record 18 of Set 10 : juba
# Processing Record 19 of Set 10 : vanavara
# Processing Record 20 of Set 10 : sao joao da barra
# Processing Record 21 of Set 10 : badiraguato
# Processing Record 22 of Set 10 : los llanos de aridane
# Processing Record 23 of Set 10 : hangu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 10 : iskateley
# Processing Record 25 of Set 10 : domoni
# Processing Record 26 of Set 10 : cervo
# Processing Record 27 of Set 10 : port-gentil
# Processing Record 28 of Set 10 : ambilobe
# Processing Record 29 of Set 10 : tankhoy
# Processing Record 30 of Set 10 : parana
# Processing Record 31 of Set 10 : cabo san lucas
# Processing Record 32 of Set 10 : orvieto
# Processing Record 33 of Set 10 : tsumeb
# Processing Record 34 of Set 10 : mackay
# Processing Record 35 of Set 10 : zyryanka
# Processing Record 36 of Set 10 : nago
# Processing Record 37 of Set 10 : asosa
# Processing Record 38 of Set 10 : axim
# Processing Record 39 of Set 10 : qeshm
# Processing Record 40 of Set 10 : yeppoon
# Processing Record 41 of Set 10 : tautira
# Processing Record 42 of Set 10 : sicamous
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 10 : lithakia
# Processing Record 44 of Set 10 : bonanza
# Processing Record 45 of Set 10 : luderitz
# Processing Record 46 of Set 10 : esmeraldas
# Processing Record 47 of Set 10 : coihaique
# Processing Record 48 of Set 10 : husavik
# Processing Record 49 of Set 10 : gornopravdinsk
# Processing Record 50 of Set 10 : alyangula
# Processing Record 0 of Set 11 : grafton
# Processing Record 1 of Set 11 : kharian
# Processing Record 2 of Set 11 : florianopolis
# Processing Record 3 of Set 11 : tessalit
# Processing Record 4 of Set 11 : quatre cocos
# Processing Record 5 of Set 11 : callaway
# Processing Record 6 of Set 11 : bulgan
# Processing Record 7 of Set 11 : ostrovnoy
# Processing Record 8 of Set 11 : nkhotakota
# Processing Record 9 of Set 11 : ust-kuyga
# Processing Record 10 of Set 11 : yabelo
# Processing Record 11 of Set 11 : san
# Processing Record 12 of Set 11 : weihe
# Processing Record 13 of Set 11 : russkiy
# Processing Record 14 of Set 11 : kiboga
# Processing Record 15 of Set 11 : statesboro
# City not found. Skipping...
# Processing Record 16 of Set 11 : kaitangata
# Processing Record 17 of Set 11 : nishihara
# Processing Record 18 of Set 11 : bayanday
# Processing Record 19 of Set 11 : grindavik
# Processing Record 20 of Set 11 : tacoronte
# Processing Record 21 of Set 11 : nador
# Processing Record 22 of Set 11 : coruripe
# Processing Record 23 of Set 11 : riyadh
# Processing Record 24 of Set 11 : lovington
# Processing Record 25 of Set 11 : buala
# Processing Record 26 of Set 11 : katobu
# Processing Record 27 of Set 11 : portobelo
# Processing Record 28 of Set 11 : leh
# Processing Record 29 of Set 11 : brejo da madre de deus
# Processing Record 30 of Set 11 : roma
# Processing Record 31 of Set 11 : cuxhaven
# Processing Record 32 of Set 11 : farafangana
# Processing Record 33 of Set 11 : los cedrales
# Processing Record 34 of Set 11 : do gonbadan
# Processing Record 35 of Set 11 : bairiki
# Processing Record 36 of Set 11 : falun
# Processing Record 37 of Set 11 : cururupu
# Processing Record 38 of Set 11 : haines junction
# Processing Record 39 of Set 11 : barra patuca
# Processing Record 40 of Set 11 : pombia
# Processing Record 41 of Set 11 : seydi
# Processing Record 42 of Set 11 : karaman
# Processing Record 43 of Set 11 : ukiah
# Processing Record 44 of Set 11 : ladario
# Processing Record 45 of Set 11 : tres arroyos
# Processing Record 46 of Set 11 : kisangani
# Processing Record 47 of Set 11 : saint-francois
# Processing Record 48 of Set 11 : fredericton
# Processing Record 49 of Set 11 : gravdal
# Processing Record 50 of Set 11 : cayenne
# Processing Record 0 of Set 12 : panzos
# Processing Record 1 of Set 12 : naron
# Processing Record 2 of Set 12 : bacolod
# Processing Record 3 of Set 12 : tarcau
# Processing Record 4 of Set 12 : sobolevo
# Processing Record 5 of Set 12 : baker city
# Processing Record 6 of Set 12 : khonsa
# Processing Record 7 of Set 12 : lakes entrance
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({
    "City" : city_list,
    "Lat" : lats_list,
    "Lng" : lngs_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Clouds" : cloud_list,
    "Wind Speed" : wind_speed_list,
    "Country" : country_list,
    "Date" : date_list    
})

# %%
weather_data.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Clouds  Wind Speed  \
# 0    George Town   5.4112  100.3354     82.40        89      40        5.75
# 1         Albany  42.6001  -73.9662     48.99        89     100        2.51
# 2      Nowa Dęba  50.4297   21.7508     62.01        32     100       10.00
# 3  Krasnoarmeysk  51.0239   45.6969     55.00        84     100        3.00
# 4   Novi Troyany  45.9427   28.8563     63.82        33      13        9.06
# 5          Mutsu  41.2894  141.2169     54.00        81      75        4.61
# 6           Hilo  19.7297 -155.0900     71.60        73      75        5.75
# 7      Kununurra -15.7667  128.7333     75.20        69       1        4.61
# 8        Mataura -46.1927  168.8643     48.99        94      94        4.00
# 9     Deputatsky  69.3000  139.9000     28.94        99     100        1.86
#
#   Country        Date
# 0      MY  1620130369
# 1      US  1620130144
# 2      PL  1620130280
# 3      RU  1620130369
# 4      UA  1620130370
# 5      JP  1620130370
# 6      US  1620130370
# 7      AU  1620130370
# 8      NZ  1620130371
# 9      RU  1620130371

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color = "green", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (06/04/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Latitude vs. Humidity Plot plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], color = "Blue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (05/04/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs. Cloudiness Plot plot
plt.scatter(weather_data["Lat"], weather_data["Clouds"], color = "Grey", edgecolor = "black")

plt.title("Latitude vs. Cloudiness (05/04/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Lattitude & Wind Speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color = "Blue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%))")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
#plt.savefig("Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_data.loc[pd.to_numeric(weather_data["Lat"]).astype(float) > 0, :]
southern_df = weather_data.loc[pd.to_numeric(weather_data["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#NoHem Max temp and Latitude
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.92x + 96.05
# The r-squared is: -0.8492727563968236
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#SoHem Max temp and Lattitude
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.65x + 84.17
# The r-squared is: 0.7188130199512097
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#NoHem Humidity and Lattitude
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.15x + 60.31
# The r-squared is: 0.11559754643806766
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#SoHem Humidity and Lattitude
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.14x + 78.41
# The r-squared is: 0.11213831142019907
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#NoHem Cloudiness and Lattitude
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Clouds']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.13x + 53.66
# The r-squared is: 0.0652267047435075
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#SoHem Cloudiness and Lattitude
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Clouds']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.39x + 62.22
# The r-squared is: 0.13858105174420993
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#NoHem Wind Speed and Lattitude
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 8.43
# The r-squared is: 0.04569763096119289
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# SOHEM Wind spped and Lattitude
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.09x + 5.59
# The r-squared is: -0.21408962842100152
# The regression does not display much of a correlation between the data sets.
